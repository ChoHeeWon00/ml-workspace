# %% [markdown]
# ## pandas
# - 특정 데이터를 DataFrame형식으로 처리

# %%
import pandas as pd

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
print( df['name'] )
df.age
# Out:
# 0     Kim
# 1     Cho
# 2    Choi
# 3      jo
# Name: name, dtype: object
# 0    20
# 1    30
# 2    40
# 3    50
# Name: age, dtype: int64

# %%
#df[ ["name", "age"] ]
df[ ["name"] ]
# Out:
#    name
# 0   Kim
# 1   Cho
# 2  Choi
# 3    jo

# %%
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
#df[ 1 : 3 ]
df[ 1 : ] # 1 ~ 끝까지
# Out:
#    name  score grade  age
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df[ 1 : 3 ]['name'] = "bbbb"
df
# Out:
# C:\Users\chohe\AppData\Local\Temp\ipykernel_1264\2108414036.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[ 1 : 3 ]['name'] = "bbbb"
# C:\Users\chohe\AppData\Local\Temp\ipykernel_1264\2108414036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[ 1 : 3 ]['name'] = "bbbb"
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1  aaaa   95.0     A   30
# 2  aaaa   90.5     B   40
# 3  aaaa   85.7     B   50

# %%
# index(조건) , column(조건)
df.loc[ 1 : 3 , "name" ] = "aaaa"
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1  aaaa   95.0     A   30
# 2  aaaa   90.5     B   40
# 3  aaaa   85.7     B   50

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.loc[ : , ['name','age'] ]
# Out:
#    name  age
# 0   Kim   20
# 1   Cho   30
# 2  Choi   40
# 3    jo   50

# %%
df.loc[ : ]
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
#df['grade'] == 'A'
df.loc[ df['grade'] == 'A']
# Out:
#   name  score grade  age
# 0  Kim  100.0     A   20
# 1  Cho   95.0     A   30

# %%
df.loc[ df['grade'] == 'A', 'grade']
# Out:
# 0    A
# 1    A
# Name: grade, dtype: object

# %%
df.loc[ df['grade'] == 'A', 'grade'] = 'CCC'
df
# Out:
#    name  score grade  age
# 0   Kim  100.0   CCC   20
# 1   Cho   95.0   CCC   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.drop(2)
# Out:
#   name  score grade  age
# 0  Kim  100.0   CCC   20
# 1  Cho   95.0   CCC   30
# 3   jo   85.7     B   50

# %%
df
# Out:
#    name  score grade  age
# 0   Kim  100.0   CCC   20
# 1   Cho   95.0   CCC   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df = df.drop(2)
df
# Out:
#   name  score grade  age
# 0  Kim  100.0   CCC   20
# 1  Cho   95.0   CCC   30
# 3   jo   85.7     B   50

# %%
df.drop( 1, inplace = True )
df
# Out:
#   name  score grade  age
# 0  Kim  100.0   CCC   20
# 3   jo   85.7     B   50

# %%
df.drop(0, axis=0, inplace=True)
df
# Out:
#   name  score grade  age
# 3   jo   85.7     B   50

# %%
df.drop('name', axis=1, inplace=True)
df
# Out:
#    score grade  age
# 3   85.7     B   50

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df['score'] < 95
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: score, dtype: bool

# %%
#df[ df['score'] < 95 ]
df.loc[ df['score'] < 95 ]
# Out:
#    name  score grade  age
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
#df[ df['score'] < 95 ]['name']
df.loc[ df['score'] < 95, 'name' ]
# Out:
# 2    Choi
# 3      jo
# Name: name, dtype: object

# %%
#df[ df['score'] < 95 ][ ['name','age'] ]
df.loc[ df['score'] < 95, ['name','age'] ]
# Out:
#    name  age
# 2  Choi   40
# 3    jo   50

# %%
df.columns
# Out:
# Index(['name', 'score', 'grade', 'age'], dtype='object')

# %%
df.values
# Out:
# array([['Kim', 100.0, 'A', 20],
#        ['Cho', 95.0, 'A', 30],
#        ['Choi', 90.5, 'B', 40],
#        ['jo', 85.7, 'B', 50]], dtype=object)

# %%
df.dtypes
# Out:
# name      object
# score    float64
# grade     object
# age        int64
# dtype: object

# %%
df['grade']
# Out:
# 0    A
# 1    A
# 2    B
# 3    B
# Name: grade, dtype: object

# %%
df['grade'].isin(['A']) # 해당 값이 있는지 확인
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: grade, dtype: bool

# %%
df[ df['grade'].isin(['A']) ]
# Out:
#   name  score grade  age
# 0  Kim  100.0     A   20
# 1  Cho   95.0     A   30

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
index_name = ['김','이','박','조']
df.index = index_name

# %%
df
# Out:
#    name  score grade  age
# 김   Kim  100.0     A   20
# 이   Cho   95.0     A   30
# 박  Choi   90.5     B   40
# 조    jo   85.7     B   50

# %%
df.index
# Out:
# Index(['김', '이', '박', '조'], dtype='object')
